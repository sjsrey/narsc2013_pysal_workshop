# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (100))

# %%
x
# Out:
# array([[ 102.28537564,   72.19671785],
#        [ 100.53205778,   69.63394545],
#        [  99.11567083,   68.41272019],
#        [ 101.75658129,   71.23944124],
#        [ 102.06623587,   71.56919931],
#        [ 100.26226672,   70.00260458],
#        [ 101.05267336,   71.09596933],
#        [  99.79445294,   69.7444905 ],
#        [ 100.79630706,   69.85634968],
#        [ 100.46427712,   71.18695775],
#        [  99.03456901,   68.69501844],
#        [  99.99095888,   70.81009059],
#        [ 100.59917098,   71.89753624],
#        [  96.91925168,   66.55366062],
#        [ 101.0954802 ,   70.82821097],
#        [ 101.46675459,   71.81886392],
#        [  99.62439018,   69.85808864],
#        [ 100.92563608,   71.2595047 ],
#        [  99.6587698 ,   68.52756638],
#        [ 100.23831047,   68.99055932],
#        [  98.70303132,   68.37929993],
#        [  97.63348569,   68.06824546],
#        [  99.50493646,   69.31362453],
#        [  97.51186533,   67.05391339],
#        [  98.36479693,   69.52923395],
#        [ 101.8454034 ,   70.46320438],
#        [ 101.27556345,   70.20545369],
#        [ 100.32730333,   70.74207095],
#        [  97.72186609,   67.88437683],
#        [  98.12143892,   69.42702084],
#        [ 100.16680307,   70.61194544],
#        [  98.45025677,   67.84670618],
#        [ 101.80847969,   71.56452185],
#        [  99.84515051,   70.17732993],
#        [ 100.11329661,   69.14066689],
#        [  98.46873319,   69.50477763],
#        [  99.39583284,   68.486688  ],
#        [  97.60430278,   68.18689322],
#        [ 102.77210054,   73.43564727],
#        [  96.79894648,   67.88143254],
#        [ 100.90448666,   69.42470547],
#        [ 100.43890736,   70.03620694],
#        [  99.6839856 ,   70.13581102],
#        [  99.6977147 ,   70.32575565],
#        [ 101.42141287,   71.54175687],
#        [  99.98011582,   70.66201763],
#        [ 100.12843796,   69.20228739],
#        [ 101.75696692,   71.3841362 ],
#        [  99.95637646,   70.94083888],
#        [ 100.29397913,   71.19269122],
#        [  98.41375785,   69.15339225],
#        [  97.37507388,   67.4072185 ],
#        [ 100.93906656,   71.03138575],
#        [ 102.14069168,   72.55266249],
#        [ 100.42497276,   71.49533394],
#        [ 103.09243942,   72.03459508],
#        [  99.9166891 ,   70.31061121],
#        [  97.57084327,   67.45014699],
#        [ 101.51193626,   71.65771523],
#        [  98.22783176,   67.60268111],
#        [  97.91672591,   69.18518585],
#        [ 100.44726591,   71.19614462],
#        [  99.58448606,   68.28582672],
#        [  99.38800943,   70.08751114],
#        [  98.26706212,   67.95895987],
#        [  99.22457119,   69.19626405],
#        [  99.880804  ,   69.23515374],
#        [ 100.81409764,   70.30561552],
#        [ 100.81947675,   70.93716714],
#        [ 100.00327686,   69.32698651],
#        [  99.61261813,   70.01445287],
#        [  97.87723668,   67.99406355],
#        [  98.54598588,   68.62442494],
#        [ 100.62740542,   70.51283617],
#        [  99.05553164,   68.87655485],
#        [ 100.6359321 ,   70.24710406],
#        [  99.85187878,   70.67354541],
#        [ 100.05377442,   69.38955822],
#        [  98.14418334,   69.55454517],
#        [ 101.65755353,   70.85359423],
#        [  99.82798487,   70.29835202],
#        [  99.93385345,   70.12570912],
#        [ 100.82391881,   70.06185405],
#        [  99.56461511,   70.93307383],
#        [ 101.46066448,   71.2954299 ],
#        [  99.61532568,   69.42775999],
#        [ 102.46371849,   71.12517837],
#        [ 101.62977597,   71.51770975],
#        [  99.66737778,   70.48923351],
#        [  99.06221415,   69.029233  ],
#        [ 100.82109134,   70.5381858 ],
#        [  99.9599453 ,   69.67404511],
#        [  96.56122863,   66.31081101],
#        [ 102.099956  ,   71.70146942],
#        [  99.4130169 ,   70.36137081],
#        [ 100.18969987,   71.44635048],
#        [ 102.27607705,   72.22607613],
#        [ 101.31324086,   70.22410022],
#        [  98.24842164,   67.24351466],
#        [  98.81414305,   68.37972979]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x105775dd0>,
#  <matplotlib.lines.Line2D at 0x10577a090>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([ 2,  5, 11,  9, 18, 20, 19, 11,  4,  1]),
#  array([ 66.31081101,  67.02329464,  67.73577826,  68.44826189,
#         69.16074552,  69.87322914,  70.58571277,  71.29819639,
#         72.01068002,  72.72316365,  73.43564727]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.05650488,  0.05650488,  0.18364087,  0.22601953,  0.26839819,
#         0.26839819,  0.21189331,  0.0706311 ,  0.04237866,  0.02825244]),
#  array([ 66.77506818,  67.48297161,  68.19087503,  68.89877845,
#         69.60668188,  70.3145853 ,  71.02248872,  71.73039215,
#         72.43829557,  73.14619899,  73.85410242]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# hist.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to generating choropleth maps.

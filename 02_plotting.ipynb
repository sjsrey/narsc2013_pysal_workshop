# %%
import numpy as np

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (100))

# %%
x
# Out:
# array([[ 100.33915465,   70.53552793],
#        [  99.70150829,   69.12624495],
#        [ 101.49443578,   70.89938877],
#        [  99.6828335 ,   69.47120666],
#        [  99.98951906,   69.93946309],
#        [ 103.16420528,   73.85410242],
#        [ 100.86438621,   70.85722302],
#        [ 100.44217658,   70.05388104],
#        [ 100.82033951,   71.18272457],
#        [  99.27732703,   68.41984873],
#        [  97.76049079,   69.30682805],
#        [ 102.1001478 ,   72.18092486],
#        [  98.7041018 ,   68.7819658 ],
#        [ 101.0523929 ,   71.44050513],
#        [  99.84316237,   71.06679112],
#        [  99.61950388,   70.31199507],
#        [  96.90066702,   68.2616696 ],
#        [  97.83939198,   67.69004507],
#        [ 100.47716356,   70.72036063],
#        [  99.00335642,   68.42354072],
#        [ 100.51716025,   70.05591856],
#        [ 101.46840195,   71.19984466],
#        [  99.62892303,   69.49177215],
#        [  99.00746061,   68.08531142],
#        [ 100.8367872 ,   70.6434873 ],
#        [ 101.80910996,   72.78175874],
#        [ 100.33409365,   70.59727589],
#        [ 101.27361801,   72.38116495],
#        [  99.11777922,   68.69820618],
#        [  99.17494234,   69.30397098],
#        [  98.81654093,   68.45524621],
#        [  99.33377435,   69.62097893],
#        [ 100.12805899,   70.90362459],
#        [ 100.36199065,   71.75947383],
#        [ 100.3450507 ,   70.246579  ],
#        [ 100.03308609,   69.93565436],
#        [  99.94428407,   68.99910455],
#        [ 100.60597619,   70.52636497],
#        [  99.72222126,   69.55900235],
#        [ 102.09777279,   72.95167163],
#        [  98.33165726,   67.38539637],
#        [ 101.89566152,   71.32499246],
#        [  99.258384  ,   68.62123837],
#        [  98.76270161,   68.97546096],
#        [ 100.23869399,   69.08128423],
#        [  99.50399357,   69.37324057],
#        [  97.53118021,   67.27822866],
#        [ 100.94836215,   69.87018667],
#        [  99.37876874,   69.41426375],
#        [ 101.32562233,   71.06015165],
#        [ 101.30067782,   70.43430622],
#        [ 100.39704563,   70.09047382],
#        [  99.66816775,   69.40436246],
#        [ 100.42572215,   70.98706293],
#        [ 101.89135687,   71.70961208],
#        [ 101.11314485,   69.79140108],
#        [  99.76620706,   70.09118798],
#        [  99.5493331 ,   69.13712466],
#        [ 100.62768201,   71.7997752 ],
#        [  98.18671392,   66.77506818],
#        [  97.97843547,   67.85337387],
#        [ 101.54449166,   71.56343309],
#        [  98.37112492,   68.70800839],
#        [  99.46113384,   68.63946187],
#        [  98.32166693,   68.7426948 ],
#        [ 101.62071953,   71.03737588],
#        [ 100.51553921,   70.61605413],
#        [  98.43510229,   68.34099269],
#        [ 100.82627108,   69.73269792],
#        [ 101.94007093,   70.91371689],
#        [ 101.2502637 ,   69.97214803],
#        [  98.79325518,   67.98666935],
#        [  96.86916655,   67.11391204],
#        [  98.60156419,   69.72920241],
#        [ 102.26278088,   70.78441916],
#        [ 100.14433111,   69.87549495],
#        [ 101.62273412,   71.38973083],
#        [  99.95545499,   70.69814311],
#        [  99.91183056,   70.23039232],
#        [ 103.34997528,   72.58663123],
#        [  98.92898178,   69.05203483],
#        [ 100.58576402,   72.38749127],
#        [ 101.90072356,   71.60923876],
#        [ 101.21978644,   70.56656961],
#        [ 101.3273061 ,   71.36589839],
#        [ 101.13978872,   71.12768647],
#        [ 100.30324487,   70.69667472],
#        [ 101.55648521,   71.61954981],
#        [  99.57435809,   68.73474708],
#        [  98.94382966,   68.92337783],
#        [ 100.39730201,   70.67746712],
#        [ 100.60413088,   71.2689107 ],
#        [ 102.99626504,   73.36669534],
#        [  99.66247059,   70.53887885],
#        [  98.96690918,   69.53648809],
#        [ 100.13435857,   70.95876825],
#        [ 101.19720298,   70.11071153],
#        [ 100.2426393 ,   70.00783544],
#        [ 100.22557822,   70.24883541],
#        [  97.53444299,   68.63001507]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x108b3ee10>,
#  <matplotlib.lines.Line2D at 0x108ba10d0>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([  4.,   4.,  13.,  16.,  19.,  19.,  15.,   5.,   3.,   2.]),
#  array([ 66.77506818,  67.48297161,  68.19087503,  68.89877845,
#         69.60668188,  70.3145853 ,  71.02248872,  71.73039215,
#         72.43829557,  73.14619899,  73.85410242]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.05650488,  0.05650488,  0.18364087,  0.22601953,  0.26839819,
#         0.26839819,  0.21189331,  0.0706311 ,  0.04237866,  0.02825244]),
#  array([ 66.77506818,  67.48297161,  68.19087503,  68.89877845,
#         69.60668188,  70.3145853 ,  71.02248872,  71.73039215,
#         72.43829557,  73.14619899,  73.85410242]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# hist.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to generating choropleth maps.

# %%
import numpy as np

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (100))

# %%
x
# Out:
# array([[ 102.68518546,   72.60577609],
#        [  99.1953629 ,   67.89553623],
#        [  99.03438748,   69.55553896],
#        [ 102.27068507,   72.87257513],
#        [  97.62188187,   68.60917279],
#        [ 100.32159309,   71.01212511],
#        [ 101.25608687,   72.75402902],
#        [ 101.24786132,   70.37158991],
#        [ 100.48418151,   70.40557597],
#        [  98.30755766,   69.11167885],
#        [ 101.67359276,   71.27682095],
#        [  99.51378403,   69.37890021],
#        [ 104.02636968,   72.45946421],
#        [  99.48989875,   71.18321711],
#        [  99.56558621,   68.82677329],
#        [  96.70481547,   67.60285165],
#        [  98.88721276,   69.73742281],
#        [  99.45871761,   68.83139531],
#        [ 102.18259218,   72.65429107],
#        [ 102.13690922,   72.48075021],
#        [ 100.59275978,   69.18853369],
#        [ 101.24703308,   71.82907984],
#        [ 100.82922686,   70.46898635],
#        [ 100.24399701,   69.40412367],
#        [ 102.01331324,   72.82364938],
#        [ 101.57069455,   71.49896527],
#        [  98.85050434,   69.65512832],
#        [  97.51464451,   68.50958797],
#        [ 102.4125319 ,   72.45579763],
#        [ 100.23780802,   69.97213718],
#        [  96.94307323,   66.93110102],
#        [  99.61829413,   68.82900356],
#        [ 100.04722223,   69.20429359],
#        [  96.90786764,   67.43556766],
#        [ 100.23534134,   69.4350275 ],
#        [  97.31418247,   67.96140689],
#        [  98.76085105,   69.08851586],
#        [  98.75655671,   69.44817946],
#        [  99.11393742,   68.51730805],
#        [  98.80459622,   67.47420582],
#        [ 100.402209  ,   70.75134142],
#        [ 101.11830114,   71.3280997 ],
#        [ 100.92961378,   71.07540271],
#        [ 100.18869476,   69.95249018],
#        [ 100.43194124,   70.44118729],
#        [ 100.37035846,   71.03527374],
#        [ 100.25046625,   70.39984832],
#        [  99.3318084 ,   69.32004027],
#        [  98.54491764,   67.61530622],
#        [  99.97068608,   69.6519933 ],
#        [ 102.18509908,   72.02575375],
#        [ 101.04912226,   69.58412392],
#        [ 102.73021622,   73.12609631],
#        [ 102.79426255,   73.29109264],
#        [  98.79547312,   68.99516319],
#        [  97.41943598,   69.02543145],
#        [  99.56453278,   69.58980539],
#        [  98.20693284,   67.58777917],
#        [ 100.77506297,   71.30545555],
#        [ 100.62846248,   70.78410118],
#        [ 100.6564314 ,   70.97220199],
#        [  97.7638663 ,   67.71695757],
#        [  97.86860713,   67.33149116],
#        [  97.94701554,   68.11617525],
#        [ 100.43153203,   70.62269046],
#        [ 101.7956908 ,   71.35470111],
#        [ 102.14583844,   71.00452336],
#        [  98.63769779,   68.56426155],
#        [  98.55454728,   68.17533164],
#        [  98.73653276,   68.37418413],
#        [  98.43712675,   68.01975574],
#        [  99.86668885,   70.39905485],
#        [  99.42354464,   69.44415424],
#        [ 102.36586856,   72.73185724],
#        [  98.67171837,   69.06408788],
#        [ 102.22704027,   71.98861845],
#        [ 101.40133855,   71.65771025],
#        [  98.81861159,   69.27966582],
#        [ 101.98220319,   71.0200389 ],
#        [  99.64689753,   68.20595606],
#        [ 100.01033776,   69.61756618],
#        [ 100.57078399,   69.74054432],
#        [ 102.3053052 ,   72.35358093],
#        [  99.4082994 ,   69.47679772],
#        [ 100.60293411,   71.84389559],
#        [ 101.04732775,   70.2278181 ],
#        [  98.13038958,   68.27285203],
#        [ 100.93697416,   71.77036342],
#        [ 101.56105714,   70.96859871],
#        [  99.04942961,   69.5353031 ],
#        [ 101.80985687,   71.89868196],
#        [  99.93552365,   71.12174392],
#        [ 100.41870524,   70.4600748 ],
#        [ 100.14592152,   71.28232382],
#        [ 101.63493003,   71.96457982],
#        [  98.94062312,   68.284162  ],
#        [  98.46424191,   68.99851941],
#        [ 100.17629963,   70.49314993],
#        [ 100.11264882,   69.37412971],
#        [  99.02675394,   69.36119754]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x109ad1a50>,
#  <matplotlib.lines.Line2D at 0x109ad1cd0>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([  4.,   9.,  11.,  17.,  12.,  10.,  16.,   8.,   7.,   6.]),
#  array([ 66.93110102,  67.56710019,  68.20309935,  68.83909851,
#         69.47509767,  70.11109683,  70.747096  ,  71.38309516,
#         72.01909432,  72.65509348,  73.29109264]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.06289316,  0.14150962,  0.1729562 ,  0.26729595,  0.18867949,
#         0.15723291,  0.25157266,  0.12578633,  0.11006304,  0.09433975]),
#  array([ 66.93110102,  67.56710019,  68.20309935,  68.83909851,
#         69.47509767,  70.11109683,  70.747096  ,  71.38309516,
#         72.01909432,  72.65509348,  73.29109264]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# dashboard.png          hist.png               menu.png
# help.png               ipython_powershell.png shortcuts.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to spatial weights.

# %%
import numpy as np

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (100))

# %%
x
# Out:
# array([[ 101.71587924,   71.45639693],
#        [ 101.94483187,   71.03404617],
#        [ 101.02895726,   71.45208976],
#        [  98.67777236,   68.06307149],
#        [ 101.07994644,   70.73389034],
#        [  99.63217743,   69.30413769],
#        [  99.24305019,   69.14476949],
#        [  99.29889424,   69.25697092],
#        [  99.48565131,   69.78585983],
#        [ 101.00919316,   72.69705143],
#        [  99.25140906,   70.61281013],
#        [  99.76749865,   69.41402127],
#        [  99.11756809,   69.94170009],
#        [ 101.38780292,   71.4337892 ],
#        [  99.86977672,   69.10636242],
#        [  99.94962919,   69.92668789],
#        [ 100.07432331,   70.54250731],
#        [  97.66907028,   66.60349752],
#        [  99.72756998,   69.48086083],
#        [  96.47801703,   65.27924509],
#        [ 100.17166772,   69.80127789],
#        [  99.71552946,   70.2123614 ],
#        [ 100.81044344,   71.72726479],
#        [ 101.20818508,   70.02191495],
#        [ 101.60908193,   70.69694761],
#        [ 100.41384644,   71.11796708],
#        [ 102.39683326,   71.96668755],
#        [ 101.01074887,   70.40302723],
#        [ 100.99095313,   71.62095271],
#        [  98.61129811,   67.95270724],
#        [  99.53919747,   68.76399555],
#        [  99.72893755,   70.39022226],
#        [ 100.98735147,   70.22809029],
#        [ 102.19876131,   71.68679619],
#        [ 100.43700371,   71.21224189],
#        [ 101.22313605,   71.11278257],
#        [ 101.34024819,   72.21130569],
#        [  98.76828125,   68.39658628],
#        [ 100.32472562,   69.28062397],
#        [ 101.20128402,   70.6193579 ],
#        [  97.00559369,   67.9722848 ],
#        [ 100.40921407,   70.20621905],
#        [  99.13872802,   68.61540547],
#        [ 101.73808049,   71.64780582],
#        [ 101.52785772,   71.51991958],
#        [  98.17967063,   68.20959608],
#        [  99.81040515,   69.15965651],
#        [ 100.55271851,   70.91028425],
#        [  97.95021104,   68.17185139],
#        [  98.25804901,   68.17021833],
#        [  97.36947702,   68.65518719],
#        [ 101.89367649,   70.67589112],
#        [  99.6106415 ,   70.40056397],
#        [ 100.35671733,   70.82239916],
#        [ 100.80414165,   69.16913253],
#        [  99.86636938,   70.87176193],
#        [ 100.66122057,   70.22493689],
#        [ 100.42252013,   71.02854969],
#        [ 100.50985521,   70.22979797],
#        [ 100.78209258,   69.82955265],
#        [ 102.01298741,   71.70943464],
#        [ 101.13754961,   70.55508662],
#        [  98.32905807,   69.99467123],
#        [  99.98903607,   69.89840907],
#        [ 101.42038162,   70.48519785],
#        [ 101.76104828,   71.57792346],
#        [  98.74603107,   68.58467025],
#        [ 101.59589215,   71.19870475],
#        [  98.23849923,   68.46245255],
#        [ 101.91486704,   72.3341412 ],
#        [ 100.10203652,   70.72490851],
#        [ 100.78874532,   70.14615058],
#        [ 101.61187492,   69.81388702],
#        [  99.99830937,   69.35874651],
#        [ 101.51726369,   70.15635464],
#        [ 100.32193419,   70.40040963],
#        [ 101.16555581,   71.09761007],
#        [ 100.81865699,   70.7143621 ],
#        [ 101.29347433,   71.47724   ],
#        [ 102.27804665,   72.29703899],
#        [  97.51439414,   66.98638062],
#        [ 100.24684543,   69.91194494],
#        [ 100.81872636,   71.06316885],
#        [ 100.4324593 ,   70.19753399],
#        [  99.49176092,   69.57675742],
#        [  98.96903838,   68.38084326],
#        [ 101.2703613 ,   70.97917824],
#        [ 100.21827694,   70.42530433],
#        [ 100.48167557,   70.80472072],
#        [  98.80376915,   68.649052  ],
#        [  98.98550547,   70.67222546],
#        [ 100.15041589,   69.56056721],
#        [  97.18335135,   67.08701164],
#        [ 101.01511351,   71.57487239],
#        [  99.614479  ,   69.48136003],
#        [ 103.34188915,   72.96842204],
#        [  98.56814242,   68.58793295],
#        [ 100.58822101,   70.1554123 ],
#        [ 100.24999702,   69.80499075],
#        [ 102.5593021 ,   71.61197139]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x1079947d0>,
#  <matplotlib.lines.Line2D at 0x107994a50>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([  1.,   1.,   2.,   6.,  10.,  17.,  25.,  19.,  14.,   5.]),
#  array([ 65.27924509,  66.04816278,  66.81708048,  67.58599817,
#         68.35491587,  69.12383356,  69.89275126,  70.66166895,
#         71.43058665,  72.19950434,  72.96842204]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.01300529,  0.01300529,  0.02601059,  0.07803176,  0.13005293,
#         0.22108998,  0.32513233,  0.24710057,  0.1820741 ,  0.06502647]),
#  array([ 65.27924509,  66.04816278,  66.81708048,  67.58599817,
#         68.35491587,  69.12383356,  69.89275126,  70.66166895,
#         71.43058665,  72.19950434,  72.96842204]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# dashboard.png          help.png               hist.png               ipython_powershell.png menu.png               shortcuts.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to spatial weights.

# %%
import numpy as np

# %% [markdown]
# ## X,Y Plots

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel('I')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = np.exp(-d)
plot(d,I)
ylabel(r'$I= \exp(-d)$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
I = d**(-2)
plot(d,I)
ylabel(r'$I= 1 / d^2$')
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2)
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex)
xlabel('d')

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()

# %%
d = np.linspace(1,10,200)
Iid = d**(-1)
plot(d,Iid, 'b-.', label = r'$I = d^{-1}$')
Iid2 = d**(-2)
plot(d,Iid2, 'r-', label = r'$I = d^{-2}$')
ylabel(r'$I$')
Inex = np.exp(-d)
plot(d,Inex, 'g--',label = r'$I = \exp(-d)$')
xlabel('d')
legend()
title('Distance Decay')

# %% [markdown]
# ## Scatter Plot

# %%
x = np.arange(100)
y = 0.5 + np.random.normal(size=(100,))
scatter(x,y)
xlabel('x')
ylabel('y')

# %%
scatter(x,y)
vlines(x.mean(),y.min(),y.max())
hlines(x.min(),x.max(),y.mean())

# %% [markdown]
# ## Distributions and Densities

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (100))

# %%
x
# Out:
# array([[  99.13731204,   69.78503029],
#        [ 100.45416069,   70.74453589],
#        [ 100.00498843,   69.74699298],
#        [  97.53116207,   68.73478405],
#        [ 101.46008787,   72.2270772 ],
#        [  98.29164916,   67.83975535],
#        [  99.07881013,   70.27967127],
#        [  99.90372241,   69.14952746],
#        [  99.28307639,   69.73900856],
#        [ 100.04129486,   68.97031463],
#        [ 101.3913607 ,   72.51972352],
#        [ 100.44052076,   70.06317746],
#        [  99.65017784,   69.2369864 ],
#        [  98.7749696 ,   67.44816654],
#        [ 100.75635166,   70.58340764],
#        [  99.44089227,   68.96790405],
#        [ 100.61493619,   70.20297122],
#        [ 103.25526737,   72.43460222],
#        [  98.74984187,   69.7397564 ],
#        [ 102.29143663,   73.33920895],
#        [ 101.95841131,   72.14885615],
#        [  99.66040975,   70.06833643],
#        [ 101.93642538,   73.17649855],
#        [  99.40348008,   69.54490992],
#        [  99.08987186,   68.11378989],
#        [  99.05818526,   68.53791578],
#        [  99.71458066,   70.56207022],
#        [ 102.16460127,   71.04788387],
#        [ 100.5202782 ,   69.35351122],
#        [  97.77430613,   66.77552133],
#        [  99.9953476 ,   70.26317482],
#        [  98.55336047,   69.78249693],
#        [  99.01284322,   68.10207651],
#        [  99.66666713,   69.65016135],
#        [ 100.58398501,   69.1759178 ],
#        [  99.44365368,   70.08435335],
#        [  99.79649238,   69.95233333],
#        [ 100.28596477,   70.79866886],
#        [ 100.38336396,   70.64467041],
#        [  98.01587878,   69.85863477],
#        [ 100.07756125,   69.49917194],
#        [  99.76652594,   69.04254648],
#        [  98.50886736,   68.36691042],
#        [  98.63164384,   68.82255759],
#        [ 100.0720465 ,   70.368458  ],
#        [  99.80597709,   70.16840111],
#        [ 100.48479675,   70.41967008],
#        [  99.64399669,   70.15511292],
#        [  99.2345418 ,   69.17705746],
#        [  99.66949068,   70.04243796],
#        [ 102.45062131,   71.90066382],
#        [ 101.13962878,   70.35560903],
#        [ 100.45003651,   69.72293807],
#        [  98.90122759,   70.21919773],
#        [ 100.96318813,   70.91491395],
#        [  99.38522382,   70.08493961],
#        [  98.13696988,   69.66121892],
#        [  99.19615674,   70.26777691],
#        [  99.72949604,   69.86658631],
#        [ 100.57299862,   70.78406314],
#        [  99.80322648,   70.14396778],
#        [ 102.31907695,   70.18958647],
#        [ 101.29420461,   71.47358695],
#        [  99.62954452,   69.01141858],
#        [ 100.33806594,   70.77600441],
#        [ 101.64514786,   71.40547051],
#        [  99.45478984,   69.76781642],
#        [ 101.96788231,   71.10517773],
#        [  97.70132754,   69.47484854],
#        [  99.79224181,   68.95828796],
#        [ 101.21159912,   69.81735273],
#        [  98.25105683,   67.66817052],
#        [  97.65304646,   69.11472382],
#        [ 101.50448398,   70.90500602],
#        [ 100.94757756,   70.80869697],
#        [  99.32285991,   69.41183495],
#        [  98.49339782,   69.21668642],
#        [ 101.78178784,   72.45823393],
#        [ 100.30711807,   70.02374302],
#        [ 100.31203363,   70.21239387],
#        [  99.60004774,   70.44792475],
#        [ 100.26477992,   69.55506613],
#        [ 100.26533826,   69.16470645],
#        [ 100.47302942,   70.61068186],
#        [  97.92483187,   68.17680085],
#        [  99.322908  ,   69.26549352],
#        [ 100.59571413,   70.57335215],
#        [ 100.90381124,   71.03956258],
#        [ 100.44984957,   69.8902577 ],
#        [  98.62041293,   68.29487548],
#        [  98.44903682,   68.4800435 ],
#        [  96.66717378,   67.67296325],
#        [  97.55005322,   67.94753555],
#        [ 100.96502036,   71.74862949],
#        [  99.42622675,   68.99384817],
#        [  98.07744077,   68.57690533],
#        [  98.21661559,   68.1963988 ],
#        [  97.27245315,   66.36768155],
#        [  97.98421637,   68.06080125],
#        [ 102.29609882,   71.08472595]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x106a78f50>,
#  <matplotlib.lines.Line2D at 0x106a7b210>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])

y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([  2.,   3.,   9.,  13.,  22.,  24.,  16.,   4.,   5.,   2.]),
#  array([ 66.36768155,  67.06483429,  67.76198703,  68.45913977,
#         69.15629251,  69.85344525,  70.55059799,  71.24775073,
#         71.94490347,  72.64205621,  73.33920895]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.02868812,  0.04303218,  0.12909653,  0.18647277,  0.3155693 ,
#         0.34425742,  0.22950494,  0.05737624,  0.07172029,  0.02868812]),
#  array([ 66.36768155,  67.06483429,  67.76198703,  68.45913977,
#         69.15629251,  69.85344525,  70.55059799,  71.24775073,
#         71.94490347,  72.64205621,  73.33920895]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Saving to a file

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# dashboard.png          hist.png               menu.png
# help.png               ipython_powershell.png shortcuts.png

# %%
from scipy.stats import gaussian_kde

# %%
y = x[:,1]
density = gaussian_kde(y)

# %%
xs = np.linspace(y.min(),y.max(),30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %%
xs = np.linspace(y.min()*.8,y.max()*1.2,30)
plot(xs, density(xs))
xlabel('y')
ylabel('f(y)')

# %% [markdown]
# There is a lot more to matplotlib. One can visit the [gallery](http://matplotlib.org/gallery.html) and pull examples in to get a sense of what is possible, and how to adapt examples for your own purposes.
#
#
# For now we move on to spatial weights.

# %% [markdown]
# # Python for Planetary Data

# %%
from IPython.display import HTML
HTML('<iframe src=http://astrogeology.usgs.gov width=1000 height=550></iframe>')
# Out:
# <iframe src=http://astrogeology.usgs.gov width=1000 height=550></iframe>

# %% [markdown]
# ### Source Code

# %% [markdown]
# Source is at http://github.com/pysal

# %% [markdown]
# ## Checking Installations

# %% [markdown]
# ### Windows 7
#
# For the purposes of this workshop it is assumed that the participants have installed version 1.8 of Anaconda Python Distribution and Folium.
#
# To check this, start a powershell:
#
# - Start button
# - type `pow` in the Search programs and files entry and hit return
# - Click **WIndows Powershell**
# - At the prompt enter `ipython` and hit return.
# - Your screen should look as follows below.

# %%
from IPython.display import Image
def show_image(img):
    i = Image(filename = img)
    return i

# %%
show_image('images/ipython_powershell.png')

# %% [markdown]
# # Introduction to IPython Notebook
#
# We will cover the basic operations/interface of the notebook which we will, in turn, use for the remainder of the workshop

# %% [markdown]
# ##What is IPython Notebook
#
# - web-based interface for working with Python (and other languages)
# - Similar in spirit to a scientific notebook
#     - record experiments
#     - document
#     - share
# - literate programming
# - simple JSON format
#     - web citizen
#     - git friendly

# %% [markdown]
# ## Starting the notebook

# %% [markdown]
# From a shell or terminal we can start the notebook with:
# ```
# ipython notebook --pylab inline
# ```
#
# This brings up the **dashboard** which will list any notebooks encountered in the current working directory.
#
# You can either open an existing notebook or create a new one from the dashboard.

# %%
show_image('images/dashboard.png')

# %% [markdown]
# ## Notebook Inteface

# %% [markdown]
# ### Menu

# %%
show_image('images/menu.png')

# %% [markdown]
# ### Help System

# %%
show_image('images/help.png')

# %% [markdown]
# ### Navigation

# %%
show_image('images/shortcuts.png')

# %% [markdown]
# ## Cell Types

# %% [markdown]
# ### Code Cells

# %%
x = range(10) # Shift-Enter to execute and create a new cell

# %%
x = range(10)
y = [ xi*3 for xi in x] # Ctrl-Return to execute but stay in the current cell

# %% [markdown]
# Comments

# %% [markdown]
# ### Text Cells

# %% [raw]
# Ctrl-m t creates a text cell

# %% [markdown]
# ### Markdown Cells

# %% [markdown]
# ```Ctrl-m m``` gives us a [Markdown] cell.
#
#
# [Markdown]: http://daringfireball.net/projects/markdown/
#
# We can then use Markdown syntax to do things like lists:
#
# - first
# - second
# - third
#   - nested one
#   - nested two
# - fourth
#
#
# As well as **LaTeX**.
#
# This is an in-line equation $\hat{\beta} = (X'X)^{-1}X'y$ for the ordinary least squares estimator.
#
# A display equation is done with
#
# $$ y = \rho W y + X\beta + \epsilon$$
#
# **NOTE**: LaTeX will only render if mathjax is available via a network connection or if it has been installed locally.

# %% [markdown]
# ## Kernel

# %% [markdown]
# ### Stoping and Restarting

# %% [raw]
# Ctrl-m .      will restart the kernel.

# %% [markdown]
# ### Exporting and Saving

# %% [markdown]
# You can save in several formats via the **File** menu entry

# %%
show_image('images/save.png')

# %% [markdown]
# ### Shell Commands

# %% [markdown]
# How many lines are in the mexico.csv data file?

# %%
! wc -l data/mexico.csv
# Out:
# 33 data/mexico.csv

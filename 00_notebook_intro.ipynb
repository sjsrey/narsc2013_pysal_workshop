# %% [markdown]
# # Introduction to IPython Notebook
#
# We will cover the basic operations/interface of the notebook which we will, in turn, use for the remainder of the workshop

# %% [markdown]
# ## Starting the notebook

# %% [markdown]
# ```
# ipython notebook --pylab inline
# ```

# %% [markdown]
# ## Notebook Inteface

# %% [markdown]
# ### Dashboard

# %% [markdown]
# ### Menu

# %% [markdown]
# ### Help System

# %% [markdown]
# ### Navigation

# %% [markdown]
# Moving with shortcuts

# %% [markdown]
# Creating new cells

# %% [markdown]
# Moving cells

# %% [markdown]
# Copying and pasting

# %% [markdown]
# ## Cell Types

# %% [markdown]
# ### Code Cells

# %% [markdown]
# Executing

# %% [markdown]
# Executing in place

# %% [markdown]
# Comments

# %% [markdown]
# ### Text Cells

# %% [markdown]
# ### LaTeX

# %% [markdown]
# ## Kernel

# %% [markdown]
# ### Stoping and Restarting

# %% [markdown]
# ### Exporting and Saving

# %% [markdown]
# ## Simple Visualization

# %%
x = arange(100)
y = x**2
plot(x,y)

# %%
x = arange(100)
y = x**2
plot(x,y)
title("My First Plot")
xlabel('x')
ylabel('y')

# %%
x = arange(100)
y = x**2
plot(x,y)
title("My First Plot")
xlabel('$x$')
ylabel('$x^2$')

# %%
import numpy as np

x = np.random.multivariate_normal([100,70],[[2.,1.7],[1.7,2.]], (100))

# %%
x
# Out:
# array([[ 100.65401881,   72.32352686],
#        [  97.07195995,   67.66509277],
#        [  98.86339278,   69.20685458],
#        [ 100.01865521,   69.2505743 ],
#        [  96.33835866,   65.37948244],
#        [  99.36613162,   70.21361859],
#        [ 100.36554202,   69.9055272 ],
#        [  97.4031258 ,   67.95120278],
#        [ 101.60435877,   71.76559143],
#        [  99.70339855,   69.66676572],
#        [  98.8256436 ,   69.99517403],
#        [  97.45452288,   68.17876569],
#        [  99.06240485,   69.53389095],
#        [  99.0711898 ,   69.20658248],
#        [ 100.36851498,   69.58166184],
#        [  97.51138888,   68.04420657],
#        [  99.56661419,   69.14621184],
#        [ 103.06657384,   73.55720264],
#        [ 100.04830913,   68.91004548],
#        [ 101.69051725,   70.98007413],
#        [  97.88724117,   70.03017598],
#        [ 103.67320934,   73.9400829 ],
#        [  99.81368337,   69.79266894],
#        [  99.61524822,   69.12446914],
#        [  98.71204771,   68.21849096],
#        [ 102.16031518,   71.61012504],
#        [ 101.78351801,   71.74239335],
#        [ 101.28199969,   69.84127144],
#        [  96.53161951,   66.43340659],
#        [ 100.17387441,   71.21210392],
#        [ 100.80007735,   71.29173752],
#        [ 100.12264019,   69.68398273],
#        [  99.94488883,   69.7150988 ],
#        [ 101.20133677,   70.95872315],
#        [ 101.91154346,   71.13497444],
#        [  98.46133613,   67.41040062],
#        [ 100.54920076,   70.85074238],
#        [ 100.95738553,   71.17621658],
#        [  98.42849208,   68.63899431],
#        [  98.2763623 ,   70.01283751],
#        [ 101.19951037,   70.28296367],
#        [  99.65296875,   68.78496601],
#        [ 100.35801253,   70.70592758],
#        [ 101.95305534,   70.63038325],
#        [  99.43906859,   70.25552053],
#        [ 100.37681938,   72.27320976],
#        [ 100.05459855,   70.93009865],
#        [ 101.18860412,   69.98295381],
#        [  97.8983595 ,   68.62621941],
#        [  97.4209666 ,   67.05809805],
#        [  99.29729897,   69.35919539],
#        [  97.03970197,   68.87665068],
#        [ 101.06232495,   70.94870431],
#        [ 102.00729996,   72.52470875],
#        [ 102.80087813,   70.46836405],
#        [  98.01994638,   68.11163344],
#        [ 101.22229833,   71.03525846],
#        [ 100.22832965,   71.29981541],
#        [ 102.02712905,   71.32108412],
#        [ 100.99744028,   70.92870444],
#        [  99.05839375,   69.99767276],
#        [  99.2753524 ,   68.04951954],
#        [  99.31805077,   69.42366192],
#        [ 103.08122712,   70.83706141],
#        [ 102.70590729,   71.97212936],
#        [  99.65066739,   68.43637432],
#        [ 100.24054654,   70.21522173],
#        [ 101.8242128 ,   71.8705423 ],
#        [  98.96572178,   69.34410294],
#        [ 101.40291584,   71.30726452],
#        [  97.53205719,   67.66387376],
#        [  99.25890374,   70.48051983],
#        [ 100.35588788,   71.45782998],
#        [ 102.29210216,   72.24093147],
#        [  98.14271088,   68.37420222],
#        [  96.22219654,   66.68793888],
#        [ 101.75396847,   71.91992446],
#        [  99.40884706,   69.99551392],
#        [  99.55954859,   70.15665534],
#        [ 103.24254852,   72.28450877],
#        [ 101.10355074,   70.61348716],
#        [ 100.54374281,   70.68979423],
#        [ 100.60700381,   69.93072278],
#        [ 101.32175668,   70.13960197],
#        [ 103.07312873,   73.68420977],
#        [  99.67496931,   69.81189986],
#        [  99.56561223,   68.9753496 ],
#        [  98.61639828,   69.72502438],
#        [ 100.09920844,   70.63030043],
#        [  99.37520263,   68.23773925],
#        [  99.12185595,   69.40898934],
#        [ 100.47032832,   69.24773818],
#        [ 100.59779164,   70.99998967],
#        [ 100.9170075 ,   70.51683798],
#        [ 100.96096878,   69.76390858],
#        [ 100.47938571,   69.82945579],
#        [  99.62771581,   69.39025735],
#        [ 101.1413527 ,   70.62458475],
#        [ 100.86624816,   71.42802498],
#        [  99.66865796,   68.90960038]])

# %%
plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x108495190>,
#  <matplotlib.lines.Line2D at 0x108495410>]

# %%
plot(x[:,0], x[:,1], "o")

# %%
x0h = hist(x[:,0])

# %%
x1h = hist(x[:,1])

# %%
n,bins,bars = hist(x[:,1])
#y = P.normpdf( bins, mu, sigma)

# %%
y = normpdf(bins, mean(x[:,1]), std(x[:,1]))

# %%
plot(bins,y)

# %%
plot(bins,y)
hist(x[:,1])
# Out:
# (array([ 1,  3,  3, 12, 17, 25, 23,  8,  5,  3]),
#  array([ 65.37948244,  66.23554248,  67.09160253,  67.94766257,
#         68.80372262,  69.65978267,  70.51584271,  71.37190276,
#         72.2279628 ,  73.08402285,  73.9400829 ]),
#  <a list of 10 Patch objects>)

# %%
plot(bins,y)
hist(x[:,1],normed=1)
# Out:
# (array([ 0.01168142,  0.03504427,  0.03504427,  0.14017708,  0.1985842 ,
#         0.29203559,  0.26867274,  0.09345139,  0.05840712,  0.03504427]),
#  array([ 65.37948244,  66.23554248,  67.09160253,  67.94766257,
#         68.80372262,  69.65978267,  70.51584271,  71.37190276,
#         72.2279628 ,  73.08402285,  73.9400829 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Saving to a figure

# %%
plot(bins,y)
hist(x[:,1],normed=1)
savefig("hist.png")

# %%
# !ls *.png
# Out:
# hist.png

# %%
w
